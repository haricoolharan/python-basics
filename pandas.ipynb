# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Constructing dataframe

# %%
data=[['hari',24],['shwin',45]]
pd.DataFrame(data,columns=['name','age'],index=[101,102])
# Out:
#       name  age
# 101   hari   24
# 102  shwin   45

# %%
array=np.arange(5,200,20).reshape(5,2)
pd.DataFrame(array,columns=['one','two'])
# Out:
#    one  two
# 0    5   25
# 1   45   65
# 2   85  105
# 3  125  145
# 4  165  185

# %%
data={'name':['ashwin','hari'],'age':[23,45]}
pd.DataFrame(data)
# Out:
#      name  age
# 0  ashwin   23
# 1    hari   45

# %%
data=[{'name':'ashwin','age':21},{'name':'hari','age':34}]
pd.DataFrame(data)
# Out:
#      name  age
# 0  ashwin   21
# 1    hari   34

# %% [markdown]
# ### READ FROM FILE

# %%
#replace with your own path
path=r'F:\dataset\NSE_instruments.csv'
data=pd.read_csv(path)
data
# Out:
#       instrument_token  exchange_token      tradingsymbol  \
# 0               258313            1009         CPSE INDEX
# 1               264713            1034  HANGSENG BEES-NAV
# 2               264969            1035          INDIA VIX
# 3               258057            1008             LIX 15
# 4               258569            1010               NI15
# ...                ...             ...                ...
# 3335            978945            3824          ZODJRDMKJ
# 3336           2916865           11394               ZOTA
# 3337           7436801           29050              ZUARI
# 3338            979713            3827          ZUARIGLOB
# 3339           4514561           17635          ZYDUSWELL
#
#                       name  last_price  expiry  strike  tick_size  lot_size  \
# 0               CPSE INDEX         0.0     NaN     0.0       0.00         0
# 1        HANGSENG BEES-NAV         0.0     NaN     0.0       0.00         0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   instrument_token  3340 non-null   int64
#  1   exchange_token    3340 non-null   int64
#  2   tradingsymbol     3340 non-null   object
#  3   name              1769 non-null   object
#  4   last_price        3340 non-null   float64
#  5   expiry            0 non-null      float64
#  6   strike            3340 non-null   float64
#  7   tick_size         3340 non-null   float64
#  8   lot_size          3340 non-null   int64
#  9   instrument_type   3340 non-null   object
#  10  segment           3340 non-null   object
#  11  exchange          3340 non-null   object
# dtypes: float64(4), int64(3), object(5)
# memory usage: 313.2+ KB

# %%
data.dtypes
# Out:
# instrument_token      int64
# exchange_token        int64
# tradingsymbol        object
# name                 object
# last_price          float64
# expiry              float64
# strike              float64
# tick_size           float64
# lot_size              int64
# instrument_type      object
# segment              object
# exchange             object
# dtype: object

# %%
data.describe()
# Out:
#        instrument_token  exchange_token  last_price  expiry  strike  \
# count      3.340000e+03     3340.000000      3340.0     0.0  3340.0
# mean       3.203030e+06    12511.830539         0.0     NaN     0.0
# std        2.178989e+06     8511.677812         0.0     NaN     0.0
# min        2.570000e+02        1.000000         0.0     NaN     0.0
# 25%        9.776010e+05     3818.750000         0.0     NaN     0.0
# 50%        3.375233e+06    13184.500000         0.0     NaN     0.0
# 75%        5.197761e+06    20303.750000         0.0     NaN     0.0
# max        8.184321e+06    31970.000000         0.0     NaN     0.0
#
#          tick_size       lot_size
# count  3340.000000    3340.000000
# mean      0.031871     323.604491
# std       0.020136    5017.606201
# min       0.000000       0.000000
# 25%       0.010000       1.000000
# 50%       0.050000       1.000000
# 75%       0.050000     100.000000
# max       0.050000  200000.000000

# %%
data.lot_size.value_counts()
# Out:
# 1         2323
# 100        789
# 0           59
# 3000        32
# 2000        28
# 4000        26
# 6000        15
# 1000        12
# 1600         8
# 1200         5
# 1500         5
# 5000         4
# 600          4
# 8000         3
# 800          3
# 200          2
# 200000       2
# 20000        2
# 7200         2
# 4500         1
# 4100         1
# 1701         1
# 10000        1
# 250          1
# 4400         1
# 400          1
# 5560         1
# 3333         1
# 16667        1
# 11765        1
# 5600         1
# 2400         1
# 5200         1
# 2500         1
# 33340        1
# Name: lot_size, dtype: int64

# %% [markdown]
# ### SLICING

# %%
data.loc[2]
# Out:
# instrument_token       264969
# exchange_token           1035
# tradingsymbol       INDIA VIX
# name                INDIA VIX
# last_price                  0
# expiry                    NaN
# strike                      0
# tick_size                   0
# lot_size                    0
# instrument_type            EQ
# segment               INDICES
# exchange                  NSE
# Name: 2, dtype: object

# %%
data.loc[[2,3,4]]
# Out:
#    instrument_token  exchange_token tradingsymbol       name  last_price  \
# 2            264969            1035     INDIA VIX  INDIA VIX         0.0
# 3            258057            1008        LIX 15     LIX 15         0.0
# 4            258569            1010          NI15       NI15         0.0
#
#    expiry  strike  tick_size  lot_size instrument_type  segment exchange
# 2     NaN     0.0        0.0         0              EQ  INDICES      NSE
# 3     NaN     0.0        0.0         0              EQ  INDICES      NSE
# 4     NaN     0.0        0.0         0              EQ  INDICES      NSE

# %%
data.loc[0:6]
# Out:
#    instrument_token  exchange_token      tradingsymbol               name  \
# 0            258313            1009         CPSE INDEX         CPSE INDEX
# 1            264713            1034  HANGSENG BEES-NAV  HANGSENG BEES-NAV
# 2            264969            1035          INDIA VIX          INDIA VIX
# 3            258057            1008             LIX 15             LIX 15
# 4            258569            1010               NI15               NI15
# 5            260617            1018          NIFTY 100          NIFTY 100
# 6            264457            1033          NIFTY 200          NIFTY 200
#
#    last_price  expiry  strike  tick_size  lot_size instrument_type  segment  \
# 0         0.0     NaN     0.0        0.0         0              EQ  INDICES
# 1         0.0     NaN     0.0        0.0         0              EQ  INDICES
# 2         0.0     NaN     0.0        0.0         0              EQ  INDICES
# ...

# %%
data.loc[2,"instrument_token"]
# Out:
# 264969

# %%
data.loc[[2,5,6],["instrument_token","tradingsymbol"]]
# Out:
#    instrument_token tradingsymbol
# 2            264969     INDIA VIX
# 5            260617     NIFTY 100
# 6            264457     NIFTY 200

# %%
#iloc[x_position,y_position]
data.iloc[2,3]
# Out:
# 'INDIA VIX'

# %%
#ioc[[x_positions][y_positions]]
data.iloc[[2,3,4],[1,3]]
# Out:
#    exchange_token       name
# 2            1035  INDIA VIX
# 3            1008     LIX 15
# 4            1010       NI15

# %%
data.iloc[3:16,4:8]
# Out:
#     last_price  expiry  strike  tick_size
# 3          0.0     NaN     0.0        0.0
# 4          0.0     NaN     0.0        0.0
# 5          0.0     NaN     0.0        0.0
# 6          0.0     NaN     0.0        0.0
# 7          0.0     NaN     0.0        0.0
# 8          0.0     NaN     0.0        0.0
# 9          0.0     NaN     0.0        0.0
# 10         0.0     NaN     0.0        0.0
# 11         0.0     NaN     0.0        0.0
# 12         0.0     NaN     0.0        0.0
# 13         0.0     NaN     0.0        0.0
# 14         0.0     NaN     0.0        0.0
# 15         0.0     NaN     0.0        0.0

# %% [markdown]
# ### Filter

# %%
data[(data['segment']=='INDICES') & (data['exchange_token']>1000)]
# Out:
#     instrument_token  exchange_token      tradingsymbol               name  \
# 0             258313            1009         CPSE INDEX         CPSE INDEX
# 1             264713            1034  HANGSENG BEES-NAV  HANGSENG BEES-NAV
# 2             264969            1035          INDIA VIX          INDIA VIX
# 3             258057            1008             LIX 15             LIX 15
# 4             258569            1010               NI15               NI15
# 5             260617            1018          NIFTY 100          NIFTY 100
# 6             264457            1033          NIFTY 200          NIFTY 200
# 7             256265            1001           NIFTY 50           NIFTY 50
# 8             268041            1047          NIFTY 500          NIFTY 500
# 9             265993            1039     NIFTY ALPHA 50     NIFTY ALPHA 50
# 10            263433            1029         NIFTY AUTO         NIFTY AUTO
# ...

# %%
data[data.tradingsymbol.str.match('NIFTY')]
# Out:
#       instrument_token  exchange_token      tradingsymbol  last_price  strike  \
# 5               260617            1018          NIFTY 100         0.0     0.0
# 6               264457            1033          NIFTY 200         0.0     0.0
# 7               256265            1001           NIFTY 50         0.0     0.0
# 8               268041            1047          NIFTY 500         0.0     0.0
# 9               265993            1039     NIFTY ALPHA 50         0.0     0.0
# 10              263433            1029         NIFTY AUTO         0.0     0.0
# 11              260105            1016         NIFTY BANK         0.0     0.0
# 12              257289            1005  NIFTY COMMODITIES         0.0     0.0
# 13              257545            1006  NIFTY CONSUMPTION         0.0     0.0
# 14              268297            1048         NIFTY CPSE         0.0     0.0
# 15              257033            1004  NIFTY DIV OPPS 50         0.0     0.0
# ...

# %%
data.tradingsymbol.str.extract(r'(\d\w*)')
# Out:
#         0
# 0     NaN
# 1     NaN
# 2     NaN
# 3      15
# 4      15
# ...   ...
# 3335  NaN
# 3336  NaN
# 3337  NaN
# 3338  NaN
# 3339  NaN
#
# [3340 rows x 1 columns]

# %%
data[data.exchange_token.isin([1042,1023])]
# Out:
#       instrument_token  exchange_token    tradingsymbol             name  \
# 18              261897            1023       NIFTY FMCG       NIFTY FMCG
# 46              266761            1042  NIFTY SMLCAP 50  NIFTY SMLCAP 50
# 1525            261889            1023       FEDERALBNK     FEDERAL BANK
#
#       last_price  expiry  strike  tick_size  lot_size instrument_type  \
# 18           0.0     NaN     0.0       0.00         0              EQ
# 46           0.0     NaN     0.0       0.00         0              EQ
# 1525         0.0     NaN     0.0       0.05         1              EQ
#
#       segment exchange
# 18    INDICES      NSE
# 46    INDICES      NSE
# 1525      NSE      NSE

# %% [markdown]
# ### NULL VALUES:

# %%
data.dropna(axis=1)
# Out:
#       instrument_token  exchange_token      tradingsymbol  last_price  strike  \
# 0               258313            1009         CPSE INDEX         0.0     0.0
# 1               264713            1034  HANGSENG BEES-NAV         0.0     0.0
# 2               264969            1035          INDIA VIX         0.0     0.0
# 3               258057            1008             LIX 15         0.0     0.0
# 4               258569            1010               NI15         0.0     0.0
# ...                ...             ...                ...         ...     ...
# 3335            978945            3824          ZODJRDMKJ         0.0     0.0
# 3336           2916865           11394               ZOTA         0.0     0.0
# 3337           7436801           29050              ZUARI         0.0     0.0
# 3338            979713            3827          ZUARIGLOB         0.0     0.0
# 3339           4514561           17635          ZYDUSWELL         0.0     0.0
#
# ...

# %%
data.fillna('Nothing').head(3)
# Out:
#    instrument_token  exchange_token      tradingsymbol               name  \
# 0            258313            1009         CPSE INDEX         CPSE INDEX
# 1            264713            1034  HANGSENG BEES-NAV  HANGSENG BEES-NAV
# 2            264969            1035          INDIA VIX          INDIA VIX
#
#    last_price   expiry  strike  tick_size  lot_size instrument_type  segment  \
# 0         0.0  Nothing     0.0        0.0         0              EQ  INDICES
# 1         0.0  Nothing     0.0        0.0         0              EQ  INDICES
# 2         0.0  Nothing     0.0        0.0         0              EQ  INDICES
#
#   exchange
# 0      NSE
# 1      NSE
# 2      NSE

# %%
data=pd.read_csv(r'F:\dataset\quantity.csv',header=None)
data.tail(500)
# Out:
#                                 0        1        2      3         4
# 30503                     58:35.5  2198612  4097499  78.40  0.539391
# 30504                     58:36.1  2198650  4098296  78.40  0.539391
# 30505                     58:36.9  2198650  4098296  78.40  0.539391
# 30506                     58:37.7  2229991  4099409  78.45  0.539391
# 30507                     58:38.2  2229991  4099409  78.40  0.539391
# ...                           ...      ...      ...    ...       ...
# 30998  2021-02-05 11:02:38.856517  2096640  4897751  97.85       NaN
# 30999  2021-02-05 11:02:40.065246  2096640  4897751  97.80       NaN
# 31000  2021-02-05 11:02:40.723529  2096640  4897751  97.75       NaN
# 31001  2021-02-05 11:02:41.798200  2096640  4897751  97.85       NaN
# 31002  2021-02-05 11:02:42.349573  2117191  4863396  97.85       NaN
#
# [500 rows x 5 columns]

# %%
data.fillna(method='ffill').tail(3)
# Out:
#                                 0        1        2      3         4
# 31000  2021-02-05 11:02:40.723529  2096640  4897751  97.75  0.539391
# 31001  2021-02-05 11:02:41.798200  2096640  4897751  97.85  0.539391
# 31002  2021-02-05 11:02:42.349573  2117191  4863396  97.85  0.539391

# %%
data.interpolate()
# Out:
#                                 0        1        2      3         4
# 0                         52:48.3  3532156  5166909  80.25  0.683611
# 1                         52:49.0  3536279  5153454  80.25  0.686196
# 2                         52:49.5  3536279  5153454  80.25  0.686196
# 3                         52:50.1  3538140  5150074  80.25  0.687008
# 4                         52:51.2  3538240  5150074  80.25  0.687027
# ...                           ...      ...      ...    ...       ...
# 30998  2021-02-05 11:02:38.856517  2096640  4897751  97.85  0.539391
# 30999  2021-02-05 11:02:40.065246  2096640  4897751  97.80  0.539391
# 31000  2021-02-05 11:02:40.723529  2096640  4897751  97.75  0.539391
# 31001  2021-02-05 11:02:41.798200  2096640  4897751  97.85  0.539391
# 31002  2021-02-05 11:02:42.349573  2117191  4863396  97.85  0.539391
#
# [31003 rows x 5 columns]

# %%
#replace with your own path
path=r'F:\dataset\NSE_instruments.csv'
data=pd.read_csv(path)
data
# Out:
#       instrument_token  exchange_token      tradingsymbol  \
# 0               258313            1009         CPSE INDEX
# 1               264713            1034  HANGSENG BEES-NAV
# 2               264969            1035          INDIA VIX
# 3               258057            1008             LIX 15
# 4               258569            1010               NI15
# ...                ...             ...                ...
# 3335            978945            3824          ZODJRDMKJ
# 3336           2916865           11394               ZOTA
# 3337           7436801           29050              ZUARI
# 3338            979713            3827          ZUARIGLOB
# 3339           4514561           17635          ZYDUSWELL
#
#                       name  last_price  expiry  strike  tick_size  lot_size  \
# 0               CPSE INDEX         0.0     NaN     0.0       0.00         0
# 1        HANGSENG BEES-NAV         0.0     NaN     0.0       0.00         0
# ...

# %%
data.drop_duplicates(subset='exchange_token',keep='last')
# Out:
#       instrument_token  exchange_token      tradingsymbol  \
# 1               264713            1034  HANGSENG BEES-NAV
# 2               264969            1035          INDIA VIX
# 4               258569            1010               NI15
# 6               264457            1033          NIFTY 200
# 8               268041            1047          NIFTY 500
# ...                ...             ...                ...
# 3335            978945            3824          ZODJRDMKJ
# 3336           2916865           11394               ZOTA
# 3337           7436801           29050              ZUARI
# 3338            979713            3827          ZUARIGLOB
# 3339           4514561           17635          ZYDUSWELL
#
#                       name  last_price  expiry  strike  tick_size  lot_size  \
# 1        HANGSENG BEES-NAV         0.0     NaN     0.0       0.00         0
# 2                INDIA VIX         0.0     NaN     0.0       0.00         0
# ...

# %% [markdown]
# ### replace columns and values
